# %% [markdown]
# <a href="https://colab.research.google.com/github/JothilakshmiAnand/AutomationCICD/blob/main/NumpyExamples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])
print (a+b)
# Out:
# [5 7 9]

# %%
arr2d = np.array([[1, 2, 3],
                 [4, 5, 6]])
print(arr2d)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,4))
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
np.arange(0,12,2)
# Out:
# array([ 0,  2,  4,  6,  8, 10])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
arr = np.array([[1,2,3],
                [4,5,6]])

print(arr.dtype)
# Out:
# int64

# %%
arr1 = np.array([10,34,65,98,100])
print(arr1[1:4])
# Out:
# [34 65 98]

# %%
arr2d = np.array([[10,20,30],
                  [40,50,60]])
print(arr2d[0,:])
# Out:
# [10 20 30]

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

print(a ** b)
# Out:
# [  1  32 729]

# %%
arr = np.array([34,10,65,23,98,100])
print(np.min((arr)))
# Out:
# 10

# %%
a = np.array([[1,2],
              [3,4]])
b = np.array([[5,6],
              [7,8]])

print(np.linalg.det(a))
# Out:
# -2.0000000000000004

# %%
arr = np.array([10,20,30,40,50])
print(arr[arr>25])
# Out:
# [30 40 50]

# %%
arr = np.arange(1,9)
#print(arr.reshape(2,4))
print(arr.flatten())
# Out:
# [1 2 3 4 5 6 7 8]

# %%
#print(np.random.rand(2,3) )
print(np.random.randint(1,10,5))
np.random.seed(42)
# Out:
# [9 1 3 7 4]

# %%
arr = np.array([10, np.nan, 20, 30, np.nan])
print(np.isnan(arr))      # identify NaN
print(arr[~np.isnan(arr)]) # remove NaN → [10. 20. 30.]
# Out:
# [False  True False False  True]
# [10. 20. 30.]
